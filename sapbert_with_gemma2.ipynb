# %% [markdown]
# new

# %%
# !head -1  '/content/icd_11_prompt_delimited.txt'
# Out:
# Disorder Name:   Disorder  of intellectual development, mild   |  Disorder Code: 6A00.0   |  Disorder Symptoms: A mild   Disorder  of intellectual development is a condition originating during the developmental period characterised by significantly below average intellectual functioning and adaptive behaviour that are approximately two to three standard deviations below the mean (approximately 0.1   2.3 percentile), based on appropriately normed, individually administered standardized tests or by comparable behavioural indicators when standardized testing is unavailable. Affected persons often exhibit difficulties in the acquisition and comprehension of complex language concepts and academic skills. Most master basic self-care, domestic, and practical activities. Persons affected by a mild   Disorder  of intellectual development can generally achieve relatively independent living and employment as adults but may require appropriate support.  Disorder  of intellectual development, mild In mild   Disorder  of intellectual development, intellectual functioning and adaptive behaviourare found to be approximately 2 3 standard deviations below the mean (approximately0.1 2.3 percentile), based on appropriately normed, individually administered standardizedtests. Where standardized tests are not available, assessment of intellectual functioning andadaptive behaviour requires greater reliance on clinical judgement, which may includethe use of behavioural indicators provided in Tables 6.1 6.4. People with mild   Disorder  ofintellectual development often exhibit difficulties in the acquisition and comprehension ofcomplex language concepts and academic skills. Most master basic self-care, domestic andpractical activities. Affected people can generally achieve relatively independent living andemployment as adults, but may require appropriate support.Neurodevelopmental   Disorder s    Disorder s of intellectual development 94 Clinical Descriptions and Diagnostic Requirements for ICD-11 Mental, Behavioural or Neurodevelopmental   Disorder s

# %%
import csv
from collections import defaultdict
import numpy as np
from sentence_transformers import SentenceTransformer
import re
from collections import Counter
import math
import pandas as pd
import os

# File paths
original_file = '/content/icd_11_prompt_delimited.txt'  # Format: Disorder Name|Disorder Code|Disorder Symptoms
user_symptoms_file = '/content/enhanced_psychology_symptoms.txt'  # Format: Symptoms only (one per line)
high_similarity_file = '/content/sapbert_high_similarity_pairs.csv'  # Output: User symptoms|predicted ICD Code|predicted Symptoms|Cosine Similarity
all_similarity_file = '/content/sapbert_all_similarity_pairs.csv'  # New: All comparisons
unmatched_log = '/content/sapbert_unmatched_icd_codes.txt'
low_similarity_log = '/content/sapbert_low_similarity_pairs.csv'
original_codes_log = '/content/sapbert_original_codes.txt'

# Debug input files
for file_path in [original_file, user_symptoms_file]:
    if not os.path.exists(file_path):
        print(f"Error: File {file_path} not found.")
        exit()
    print(f"File size of {file_path}: {os.path.getsize(file_path)} bytes")
    with open(file_path, 'r', encoding='utf-8') as f:
        print(f"First 2 lines of {file_path}:")
        for i, line in enumerate(f):
            if i < 2:
                print(line.strip())
            else:
                break

# Expanded typo/synonym correction dictionary for ICD terms
typo_corrections = {
    'behaviour': 'behavior',
    'behaviours': 'behaviors',
    'adaptative': 'adaptive',
    'intelectual': 'intellectual',
    'standerd': 'standard',
    'deviation': 'deviations',
    'cognitive': 'intellectual',  # Medical synonym
    'mental': 'intellectual',
    'adaptive behaviour': 'adaptive behavior',
    'belowaverage': 'below average',
    'standardised': 'standardized',
    'percentile': 'percentiles',
}

# Normalize ICD code: remove prefixes, uppercase, strip whitespace
def normalize_code(code):
    code = re.sub(r'^\s*Disorder Code:\s*', '', code, flags=re.IGNORECASE)
    code = re.sub(r'\s+', '', code)
    return code.upper()

# Preprocess text: lowercase, remove punctuation, correct typos/synonyms
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    for wrong, correct in typo_corrections.items():
        text = text.replace(wrong, correct)
    return text

# TF-IDF cosine similarity function (fallback)
def compute_tf_idf_cosine(original, user):
    docs = [preprocess_text(original), preprocess_text(user)]
    vocab = list(set(word for doc in docs for word in doc.split()))
    tf_docs = [[Counter(doc.split()).get(word, 0) / len(doc.split()) for word in vocab] for doc in docs]
    N = len(docs)
    idf = [math.log(N / (1 + sum(1 for doc in docs if word in doc))) for word in vocab]
    tfidf_docs = [[tf * idf_val for tf, idf_val in zip(tf_vector, idf)] for tf_vector in tf_docs]
    vec1, vec2 = np.array(tfidf_docs[0]), np.array(tfidf_docs[1])
    dot = np.dot(vec1, vec2)
    norm1, norm2 = np.linalg.norm(vec1), np.linalg.norm(vec2)
    return dot / (norm1 * norm2) if norm1 > 0 and norm2 > 0 else 0.0

# Read original ICD records
original_records = {}
original_codes = set()
with open(original_file, 'r', encoding='utf-8') as f:
    reader = csv.reader(f, delimiter='|')
    for row in reader:
        if len(row) == 3:
            name, code, symptoms = [field.strip() for field in row]
            code = normalize_code(code)
            original_records[code] = {'name': name, 'symptoms': preprocess_text(symptoms), 'raw_symptoms': symptoms}
            original_codes.add(code)
        else:
            print(f"Skipping malformed original record: {row}")

# Save original codes
with open(original_codes_log, 'w', encoding='utf-8') as f:
    for code in sorted(original_codes):
        f.write(f"{code}\n")
print(f"Saved {len(original_codes)} original ICD codes to {original_codes_log}")

# Read user symptoms
user_symptoms_list = []
with open(user_symptoms_file, 'r', encoding='utf-8') as f:
    for line in f:
        symptom = line.strip()
        if symptom:
            user_symptoms_list.append(preprocess_text(symptom))
print(f"Read {len(user_symptoms_list)} user symptom records from {user_symptoms_file}")

# Initialize embedding method with SapBERT
try:
    embedding_function = SentenceTransformer('cambridgeltl/SapBERT-from-PubMedBERT-fulltext')
    print("Using SapBERT embeddings")
    use_pubmedbert = True
except Exception as e:
    print(f"Error initializing SapBERT: {e}. Falling back to TF-IDF.")
    use_pubmedbert = False

# Compute cosine similarities with progress tracking and batching
results = []
low_similarity_pairs = []
high_similarity_pairs = []
total_pairs = len(user_symptoms_list) * len(original_records)
processed_pairs = 0
batch_size = 100

# Pre-embed original symptoms for efficiency
if use_pubmedbert:
    original_embeddings = {
        code: embedding_function.encode(data['symptoms'])
        for code, data in original_records.items()
    }

# Process user symptoms in batches
for i in range(0, len(user_symptoms_list), batch_size):
    batch = user_symptoms_list[i:i + batch_size]

    # Embed batch of user symptoms
    if use_pubmedbert:
        user_embeddings = embedding_function.encode(batch)

    for j, user_symptoms in enumerate(batch):
        for original_code, original_data in original_records.items():
            try:
                if use_pubmedbert:
                    user_vector = np.array(user_embeddings[j])
                    original_vector = original_embeddings[original_code]
                    cosine_similarity = np.dot(original_vector, user_vector) / (
                        np.linalg.norm(original_vector) * np.linalg.norm(user_vector)
                    )
                else:
                    cosine_similarity = compute_tf_idf_cosine(original_data['symptoms'], user_symptoms)

                results.append([user_symptoms, original_code, original_data['raw_symptoms'], cosine_similarity])
                if cosine_similarity < 0.9:
                    low_similarity_pairs.append([user_symptoms, original_code, original_data['raw_symptoms'], f"{cosine_similarity:.4f}"])
                if cosine_similarity > 0.75:
                    high_similarity_pairs.append([user_symptoms, original_code, original_data['raw_symptoms'], f"{cosine_similarity:.4f}"])

                # Debug similarity scores
                if processed_pairs < 10 or cosine_similarity > 0.9:
                    print(f"Similarity {cosine_similarity:.4f} for user symptoms vs ICD code {original_code}")

                processed_pairs += 1
                if processed_pairs % 1000 == 0:
                    print(f"Processed {processed_pairs}/{total_pairs} pairs ({processed_pairs/total_pairs*100:.2f}%)")
            except Exception as e:
                print(f"Error processing user symptoms with ICD code {original_code}: {e}")

# Save all similarity pairs
if results:
    with open(all_similarity_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['User symptoms', 'predicted ICD Code', 'predicted Symptoms', 'Cosine Similarity'])
        writer.writerows([[row[0], row[1], row[2], f"{row[3]:.4f}"] for row in results])
    print(f"Logged {len(results)} total similarity pairs to {all_similarity_file}")

# Save high similarity pairs (> 0.75)
if high_similarity_pairs:
    with open(high_similarity_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['User symptoms', 'predicted ICD Code', 'predicted Symptoms', 'Cosine Similarity'])
        writer.writerows(high_similarity_pairs)
    print(f"Logged {len(high_similarity_pairs)} pairs with similarity > 0.75 to {high_similarity_file}")

# Save low similarity pairs
if low_similarity_pairs:
    with open(low_similarity_log, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['User symptoms', 'predicted ICD Code', 'predicted Symptoms', 'Cosine Similarity'])
        writer.writerows(low_similarity_pairs)
    print(f"Logged {len(low_similarity_pairs)} pairs with similarity < 0.9 to {low_similarity_log}")

# Log unmatched ICD codes
matched_codes = set([row[1] for row in high_similarity_pairs])
unmatched_codes = [code for code in original_codes if code not in matched_codes]
if unmatched_codes:
    with open(unmatched_log, 'w', encoding='utf-8') as f:
        for code in unmatched_codes:
            f.write(f"{code}\n")
    print(f"Logged {len(unmatched_codes)} unmatched ICD codes to {unmatched_log}")

# Validation summary
total_original = len(original_records)
total_user_symptoms = len(user_symptoms_list)
matched_codes_count = len(matched_codes)
average_matches_per_symptom = len(high_similarity_pairs) / total_user_symptoms if total_user_symptoms > 0 else 0

# Compute average similarity per user symptom set
similarities_per_symptom = defaultdict(list)
for result in results:
    similarities_per_symptom[result[0]].append(float(result[3]))
average_similarities = {symptom: np.mean(sims) for symptom, sims in similarities_per_symptom.items()}

print("\nValidation Summary:")
print(f"Total original ICD records: {total_original}")
print(f"Total user symptom records: {total_user_symptoms}")
print(f"Matched ICD codes: {matched_codes_count} ({matched_codes_count / total_original * 100:.2f}%)")
print(f"Average matches per user symptom set: {average_matches_per_symptom:.2f}")
print(f"High similarity pairs (> 0.75): {len(high_similarity_pairs)}")
print(f"Total similarity pairs: {len(results)}")
print("\nAverage Cosine Similarity per User Symptom Set:")
for symptom, avg_sim in sorted(average_similarities.items(), key=lambda x: x[1], reverse=True):
    print(f"User symptoms: {symptom[:50]}...: {avg_sim:.4f}")

# Overall average similarity
if results:
    overall_avg = np.mean([float(result[3]) for result in results])
    print(f"\nOverall Average Cosine Similarity: {overall_avg:.4f}")
else:
    print("No results computed. Check embedding errors or input data.")
# Out:
# File size of /content/icd_11_prompt_delimited.txt: 1280665 bytes
# First 2 lines of /content/icd_11_prompt_delimited.txt:
# Disorder Name:   Disorder  of intellectual development, mild   |  Disorder Code: 6A00.0   |  Disorder Symptoms: A mild   Disorder  of intellectual development is a condition originating during the developmental period characterised by significantly below average intellectual functioning and adaptive behaviour that are approximately two to three standard deviations below the mean (approximately 0.1   2.3 percentile), based on appropriately normed, individually administered standardized tests or by comparable behavioural indicators when standardized testing is unavailable. Affected persons often exhibit difficulties in the acquisition and comprehension of complex language concepts and academic skills. Most master basic self-care, domestic, and practical activities. Persons affected by a mild   Disorder  of intellectual development can generally achieve relatively independent living and employment as adults but may require appropriate support.  Disorder  of intellectual development, mild In mild   Disorder  of intellectual development, intellectual functioning and adaptive behaviourare found to be approximately 2 3 standard deviations below the mean (approximately0.1 2.3 percentile), based on appropriately normed, individually administered standardizedtests. Where standardized tests are not available, assessment of intellectual functioning andadaptive behaviour requires greater reliance on clinical judgement, which may includethe use of behavioural indicators provided in Tables 6.1 6.4. People with mild   Disorder  ofintellectual development often exhibit difficulties in the acquisition and comprehension ofcomplex language concepts and academic skills. Most master basic self-care, domestic andpractical activities. Affected people can generally achieve relatively independent living andemployment as adults, but may require appropriate support.Neurodevelopmental   Disorder s    Disorder s of intellectual development 94 Clinical Descriptions and Diagnostic Requirements for ICD-11 Mental, Behavioural or Neurodevelopmental   Disorder s
# Disorder Name:   Disorder  of intellectual development, moderate  |  Disorder Code: 6A00.1  |  Disorder Symptoms: A moderate   Disorder  of intellectual development is a condition originating during the developmental period characterised by significantly below average intellectual functioning and adaptive behaviour that are approximately three to four standard deviations below the mean (approximately 0.003   0.1 percentile), based on appropriately normed, individually administered standardized tests or by comparable behavioural indicators when standardized testing is unavailable. Language and capacity for acquisition of academic skills of persons affected by a moderate   Disorder  of intellectual development vary but are generally limited to basic skills. Some may master basic self-care, domestic, and practical activities. Most affected persons require considerable and consistent support in order to achieve independent living and employment as adults.  Disorder  of intellectual development, moderate In moderate   Disorder  of intellectual development, intellectual functioning and adaptivebehaviour are found to be approximately 3 4 standard deviations below the mean(approximately 0.003 0.1 percentile), based on appropriately normed, individuallyadministered standardized tests. Where standardized tests are not available, assessmentof intellectual functioning and adaptive behaviour requires greater reliance on clinicaljudgement, which may include the use of behavioural indicators provided in Tables6.1 6.4. Language and capacity for acquisition of academic skills of people affected bymoderate   Disorder  of intellectual development vary but are generally limited to basic skills.Some may master basic self-care, domestic and practical activities. Most affected peoplerequire considerable and consistent support in order to achieve independent living andemployment as adults.
# File size of /content/enhanced_symptoms.txt: 18992 bytes
# First 2 lines of /content/enhanced_symptoms.txt:
# 1. Scholastic backwardness, Can’t understand money concepts, Behavioral concerns in social situations, Needs help after defecation, Phrasal speech, Need based expressive language, Stubbornness, Bites his hand if wish is not fulfilled, Lacks attention and concentration, Low sitting tolerance, Can’t eat rice with his hands, Difficulty with learning new skills, Poor short-term memory, Delayed developmental milestones, Hyperactive tendencies, Easily distracted, Poor impulse control, Trouble following multi-step instructions, Limited problem-solving abilities
# 2. Scholastic backwardness, Delayed reading skills, Difficulty with writing tasks, Minimal short-term memory issues, Struggles with academic retention, Slow processing of new information, Challenges in academic comprehension, Needs repeated instructions
# Saved 368 original ICD codes to /content/sapbert_original_codes.txt
# Read 55 user symptom records from /content/enhanced_symptoms.txt
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name cambridgeltl/SapBERT-from-PubMedBERT-fulltext. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/198 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Using SapBERT embeddings
# Similarity 0.6022 for user symptoms vs ICD code 6A00.0
# Similarity 0.5894 for user symptoms vs ICD code 6A00.1
# Similarity 0.5947 for user symptoms vs ICD code 6A00.2
# Similarity 0.5990 for user symptoms vs ICD code 6A00.3
# Similarity 0.5310 for user symptoms vs ICD code 6A00.4
# Similarity 0.5612 for user symptoms vs ICD code 6A01.0
# Similarity 0.6280 for user symptoms vs ICD code 6A01.1
# Similarity 0.6081 for user symptoms vs ICD code 6A01.Y
# Similarity 0.6081 for user symptoms vs ICD code 6A01.Z
# Similarity 0.4390 for user symptoms vs ICD code 6A02.0
# Processed 1000/20240 pairs (4.94%)
# Processed 2000/20240 pairs (9.88%)
# Processed 3000/20240 pairs (14.82%)
# Processed 4000/20240 pairs (19.76%)
# Processed 5000/20240 pairs (24.70%)
# Processed 6000/20240 pairs (29.64%)
# Processed 7000/20240 pairs (34.58%)
# Processed 8000/20240 pairs (39.53%)
# Processed 9000/20240 pairs (44.47%)
# Processed 10000/20240 pairs (49.41%)
# Processed 11000/20240 pairs (54.35%)
# Processed 12000/20240 pairs (59.29%)
# Processed 13000/20240 pairs (64.23%)
# Processed 14000/20240 pairs (69.17%)
# Processed 15000/20240 pairs (74.11%)
# Processed 16000/20240 pairs (79.05%)
# Processed 17000/20240 pairs (83.99%)
# Processed 18000/20240 pairs (88.93%)
# Processed 19000/20240 pairs (93.87%)
# Processed 20000/20240 pairs (98.81%)
# Logged 20240 total similarity pairs to /content/sapbert_all_similarity_pairs.csv
# Logged 20240 pairs with similarity < 0.9 to /content/sapbert_low_similarity_pairs.csv
# Logged 368 unmatched ICD codes to /content/sapbert_unmatched_icd_codes.txt
#
# Validation Summary:
# Total original ICD records: 368
# Total user symptom records: 55
# Matched ICD codes: 0 (0.00%)
# Average matches per user symptom set: 0.00
# High similarity pairs (> 0.75): 0
# Total similarity pairs: 20240
#
# Average Cosine Similarity per User Symptom Set:
# User symptoms: 18 no ageappropriate development no speech partial...: 0.5841
# User symptoms: 29 no age appropriate intelligence plays aloof stu...: 0.5720
# User symptoms: 36 no ageappropriate intelligence follows simple i...: 0.5660
# User symptoms: 52 scholastic backwardness unclear speech forgetti...: 0.5650
# User symptoms: 4 lacks in comprehending social norms partial eye ...: 0.5623
# User symptoms: 44 talks fast impulsive cant delay gratification p...: 0.5589
# User symptoms: 37 scholastic backwardness lacks attention and con...: 0.5517
# User symptoms: 53 no ageappropriate development speech delay limi...: 0.5443
# User symptoms: 50 hyper restless low sitting tolerance impulsive ...: 0.5432
# User symptoms: 5 scholastic backwardness lacks money concept cant...: 0.5424
# User symptoms: 55 no ageappropriate development monosyllabic spee...: 0.5393
# User symptoms: 12 no speech partial eye contact can follow some i...: 0.5372
# User symptoms: 28 one word speech no age appropriate intelligence...: 0.5369
# User symptoms: 14 one word speech limited vocabulary aloof play h...: 0.5298
# User symptoms: 22 one word speech no expressive language robotic ...: 0.5236
# User symptoms: 46 unclear speech loves creative play likes to mak...: 0.5234
# User symptoms: 33 hyper restless lacks patience toilet training n...: 0.5231
# User symptoms: 8 aloof play lacks expressive language gibberish t...: 0.5197
# User symptoms: 25 delayed speech monosyllabic speech unclear hype...: 0.5140
# User symptoms: 15 no social conformity gets scared easily in soci...: 0.5125
# User symptoms: 20 aloof play lacks expressive speech unclear spee...: 0.5120
# User symptoms: 11 no ageappropriate development monosyllabic spee...: 0.5113
# User symptoms: 26 repetitive and restricted behaviors self talkin...: 0.5079
# User symptoms: 9 hyper echolalia toilet control not attained aloo...: 0.5071
# User symptoms: 19 no ageappropriate development delayed speech re...: 0.5066
# User symptoms: 17 sensorial sensitivities auditory limited social...: 0.5062
# User symptoms: 48 hyper phrasal speech echolalia parallel play on...: 0.5028
# User symptoms: 35 scholastic backwardness lacks patience needs im...: 0.4986
# User symptoms: 10 babbling speech hyper on medication toilet trai...: 0.4979
# User symptoms: 51 no ageappropriate development delayed speech on...: 0.4945
# User symptoms: 1 scholastic backwardness cant understand money co...: 0.4910
# User symptoms: 7 not interested in studies doesnt read the questi...: 0.4897
# User symptoms: 41 scholastic backwardness stranger anxiety perfor...: 0.4891
# User symptoms: 6 scholastic backwardness speaks fast epilepsy sil...: 0.4836
# User symptoms: 49 hyper stubborn cant delay gratification low sit...: 0.4818
# User symptoms: 34 scholastic backwardness lacks attention and con...: 0.4805
# User symptoms: 16 scholastic backwardness speaks fast epilepsy si...: 0.4768
# User symptoms: 40 talks very slowly scholastic backwardness hesit...: 0.4684
# User symptoms: 30 scholastic backwardness getting angry quickly s...: 0.4626
# User symptoms: 3 scholastic backwardness less sleep has performan...: 0.4567
# User symptoms: 54 scholastic backwardness unacceptable behaviors ...: 0.4556
# User symptoms: 31 scholastic backwardness delayed academic progre...: 0.4535
# User symptoms: 23 scholastic backwardness cant understand money c...: 0.4526
# User symptoms: 24 scholastic backwardness forgets whatever is tau...: 0.4493
# User symptoms: 42 scholastic backwardness likes to be with elders...: 0.4490
# User symptoms: 32 scholastic backwardness lacks attention and con...: 0.4468
# User symptoms: 13 scholastic backwardness lacks attention and con...: 0.4430
# User symptoms: 2 scholastic backwardness delayed reading skills d...: 0.4399
# User symptoms: 38 unclear speech no age appropriate maturity need...: 0.4276
# User symptoms: 39 hearing impairment due to meningitis scholastic...: 0.4260
# User symptoms: 45 unclear speech no age appropriate maturity scho...: 0.4205
# User symptoms: 21 speech delay scholastic backwardness downs synd...: 0.4201
# User symptoms: 43 scholastic backwardness slow academic progress ...: 0.4150
# User symptoms: 47 writes slowly scholastic backwardness challenge...: 0.3970
# User symptoms: 27 unclear speech no age appropriate maturity need...: 0.3911
#
# Overall Average Cosine Similarity: 0.4939

# %%
# Step 1: Install required libraries
# !pip install langchain langchain-community langchain-huggingface langchain-ollama faiss-cpu transformers torch ollama langgraph -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 57.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.2/153.2 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 20.7 MB/s eta 0:00:00

# %%
#cell 1
# Install required Python libraries (remove langchain-hub)
# !pip install langchain langchain-community faiss-cpu ollama flask langgraph -q

# Install Ollama in Colab
# !curl -fsSL https://ollama.com/install.sh | sh

# Start Ollama server in the background with subprocess for better control
import subprocess
import time
import os

# Start Ollama server and check if it's running
try:
    subprocess.Popen(["ollama", "serve"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Starting Ollama server...")
    time.sleep(5)  # Wait for server to initialize
except Exception as e:
    print(f"Error starting Ollama server: {e}")
    raise

# Verify server is running by checking API availability
import requests
try:
    response = requests.get("http://127.0.0.1:11434")
    if response.status_code == 200:
        print("Ollama server is running at 127.0.0.1:11434")
    else:
        print("Ollama server not responding")
        raise Exception("Ollama server failed to start")
except requests.ConnectionError:
    print("Error: Could not connect to Ollama server. Ensure 'ollama serve' is running.")
    raise

# Pull gemma2:27b model (takes time, ~27GB)
try:
    subprocess.run(["ollama", "pull", "gemma2:9b"], check=True)
    print("Successfully pulled gemma2:9b model")
except subprocess.CalledProcessError as e:
    print(f"Error pulling model: {e}")
    raise

# Verify Ollama is running and model is available
try:
    result = subprocess.run(["ollama", "list"], capture_output=True, text=True)
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print(f"Error listing models: {e}")
    raise
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Starting Ollama server...
# Ollama server is running at 127.0.0.1:11434
# Successfully pulled gemma2:9b model
# NAME         ID              SIZE      MODIFIED
# gemma2:9b    ff02c3702f32    5.4 GB    Less than a second ago

# %%
import csv
import os
import numpy as np
import pandas as pd
from langchain_core.documents import Document
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings # Use HuggingFaceEmbeddings
from langchain_ollama import OllamaEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.llms import Ollama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
# from sentence_transformers import SentenceTransformer # Remove direct import to avoid conflicts

# Configuration
INPUT_ICD_PATH = '/content/icd_11_prompt_delimited.txt'
ALL_SIMILARITY_PATH = '/content/sapbert_all_similarity_pairs.csv'
TOP5_SIMILARITY_PATH = '/content/sapbert_top5_similarity_pairs.csv'
VECTORESTORE_BASE = '/content/vectorstore'
MODEL = "gemma2:9b"  # For LLM only
SAFE_MODEL = MODEL.replace(":", "")
# Use HuggingFaceEmbeddings compatible model name
EMBEDDING_MODEL_NAME = "cambridgeltl/SapBERT-from-PubMedBERT-fulltext"
PERSIST_DIR = os.path.join(VECTORESTORE_BASE, f"faiss_index-{EMBEDDING_MODEL_NAME.replace('/', '_').replace('-', '_')}-top5")
BATCH_SIZE = 50
TOP_K = 5  # Number of top matches to retrieve

# Step 1: Load original ICD data to get disorder names
def load_icd_data(file_path):
    icd_data = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter='|')
        for row in reader:
            if len(row) == 3:
                name, code, symptoms = [field.strip() for field in row]
                code = normalize_code(code)
                icd_data[code] = {'name': name, 'symptoms': symptoms}
            else:
                print(f"Skipping malformed ICD record: {row}")
    return icd_data

def normalize_code(code):
    code = re.sub(r'^\s*Disorder Code:\s*', '', code, flags=re.IGNORECASE)
    code = re.sub(r'\s+', '', code)
    return code.upper()

# Step 2: Filter top 5 similarity pairs per user symptom set
def filter_top5_similarity_pairs(input_file, output_file, top_k=5):
    if os.path.exists(output_file):
        print(f"Top 5 similarity pairs file already exists at {output_file}. Skipping filtering.")
        return
    try:
        df = pd.read_csv(input_file)
        df['Cosine Similarity'] = df['Cosine Similarity'].astype(float)
        # Group by User symptoms and select top k matches
        df_top_k = df.groupby('User symptoms').apply(
            lambda x: x.nlargest(top_k, 'Cosine Similarity')
        ).reset_index(drop=True)
        df_top_k.to_csv(output_file, index=False)
        print(f"Saved {len(df_top_k)} top {top_k} similarity pairs to {output_file}")
    except Exception as e:
        print(f"Error filtering top 5 similarity pairs: {e}")
        raise

# Step 3: Build FAISS vectorstore with SapBERT embeddings of user symptoms
def build_sapbert_vectorstore():
    if os.path.exists(PERSIST_DIR):
        print(f"Vectorstore already exists at {PERSIST_DIR}. Skipping build.")
        return

    print("Building SapBERT-based vectorstore for top 5 user symptoms...")

    # Filter top 5 similarity pairs
    filter_top5_similarity_pairs(ALL_SIMILARITY_PATH, TOP5_SIMILARITY_PATH, top_k=TOP_K)

    # Load ICD data for metadata
    icd_data = load_icd_data(INPUT_ICD_PATH)

    # Load top 5 similarity pairs
    try:
        df_top_k = pd.read_csv(TOP5_SIMILARITY_PATH)
    except Exception as e:
        print(f"Error loading top 5 similarity pairs: {e}")
        raise

    # Initialize HuggingFaceEmbeddings with SapBERT model - This is the embedding function to use with FAISS
    try:
        embedding_function = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL_NAME, cache_folder="/content/hf_cache")
        print(f"Using HuggingFaceEmbeddings with model: {EMBEDDING_MODEL_NAME}")
    except Exception as e:
        print(f"Error initializing HuggingFaceEmbeddings: {e}")
        raise

    documents = []

    # Create documents
    for _, row in df_top_k.iterrows():
        user_symptoms = row['User symptoms']
        predicted_code = row['predicted ICD Code']
        predicted_symptoms = row['predicted Symptoms']
        similarity = row['Cosine Similarity']

        # Get disorder name from original ICD data
        disorder_name = icd_data.get(predicted_code, {}).get('name', 'Unknown')

        # Create document with metadata
        full_text = f"Disorder Name: {disorder_name} | Disorder Code: {predicted_code} | Disorder Symptoms: {predicted_symptoms} | User Symptoms: {user_symptoms} | Cosine Similarity: {similarity:.4f}"
        doc = Document(
            page_content=full_text,
            metadata={
                'user_symptoms': user_symptoms,
                'predicted_code': predicted_code,
                'disorder_name': disorder_name,
                'cosine_similarity': similarity
            }
        )
        documents.append(doc)

    if not documents:
        print("Error: No valid records found to build vectorstore.")
        return

    print(f"Embedding {len(documents)} records...")
    try:
        # Create FAISS vectorstore using HuggingFaceEmbeddings
        # Pass the embedding_function (HuggingFaceEmbeddings) directly to FAISS.from_documents
        vectorstore = FAISS.from_documents(documents, embedding_function)
        vectorstore.save_local(PERSIST_DIR)
        print(f"Vectorstore built and saved at {PERSIST_DIR}")
    except Exception as e:
        print(f"Error building vectorstore: {e}")
        raise

# Step 4: Load vectorstore and set up RAG pipeline
def setup_rag_pipeline():
    try:
        # Load vectorstore using HuggingFaceEmbeddings
        # Pass the embedding_function (HuggingFaceEmbeddings) directly to FAISS.load_local
        embedding_function = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL_NAME, cache_folder="/content/hf_cache")
        vectorstore = FAISS.load_local(
            PERSIST_DIR,
            embedding_function,
            allow_dangerous_deserialization=True
        )
        retriever = vectorstore.as_retriever(search_kwargs={"k": TOP_K})
    except Exception as e:
        print(f"Error loading vectorstore: {e}")
        raise

    # Initialize LLM
    try:
        llm = Ollama(model=MODEL)
    except Exception as e:
        print(f"Error initializing LLM: {e}")
        raise

    # RAG prompt
    rag_prompt = ChatPromptTemplate.from_messages([
        ("system", """You are a medical diagnosis assistant. Use the provided ICD-11 context to identify the most likely diagnosis. Provide the disorder name, code, and explain why the symptoms match. If the context is insufficient, state so. Include a disclaimer that you are not a medical professional and a comprehensive evaluation by a qualified healthcare professional is needed."""),
        ("human", "Context: {context}\n\nQuestion: {question}")
    ])

    # RAG chain
    rag_chain = (
        {"context": lambda x: "\n\n".join([d.page_content for d in retriever.invoke(x["question"])]), "question": RunnablePassthrough()}
        | rag_prompt
        | llm
        | StrOutputParser()
    )
    return rag_chain

# Step 5: Test RAG pipeline
def test_rag():
    build_sapbert_vectorstore()
    rag_chain = setup_rag_pipeline()

    query = "Engagement in repetitive patterns of behavior or restricted interests; Intellectual functioning below age-expected norms; Participates in routine household tasks; Delayed academic performance relative to peers; Hypersensitivity or hyposensitivity to sensory stimuli; Verbalizes thoughts aloud to self; Rigid insistence on specific routines involving phone use; Limited reciprocal social interaction; Challenges adjusting to changes in routine or environment; Monotonous or atypical speech patterns; Exceptional visual or detailed memory recall."
    try:
        response = rag_chain.invoke({"question": query})
        print(f"Query: {query}\nResponse: {response}")
    except Exception as e:
        print(f"Error in RAG: {e}")

# Run the pipeline
if __name__ == "__main__":
    test_rag()
# Out:
# Building SapBERT-based vectorstore for top 5 user symptoms...
# /tmp/ipython-input-2487910066.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_top_k = df.groupby('User symptoms').apply(
# Saved 275 top 5 similarity pairs to /content/sapbert_top5_similarity_pairs.csv
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name cambridgeltl/SapBERT-from-PubMedBERT-fulltext. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/198 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Using HuggingFaceEmbeddings with model: cambridgeltl/SapBERT-from-PubMedBERT-fulltext
# Embedding 275 records...
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name cambridgeltl/SapBERT-from-PubMedBERT-fulltext. Creating a new one with mean pooling.
# Vectorstore built and saved at /content/vectorstore/faiss_index-cambridgeltl_SapBERT_from_PubMedBERT_fulltext-top5
# /tmp/ipython-input-2487910066.py:152: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model=MODEL)
# Query: Engagement in repetitive patterns of behavior or restricted interests; Intellectual functioning below age-expected norms; Participates in routine household tasks; Delayed academic performance relative to peers; Hypersensitivity or hyposensitivity to sensory stimuli; Verbalizes thoughts aloud to self; Rigid insistence on specific routines involving phone use; Limited reciprocal social interaction; Challenges adjusting to changes in routine or environment; Monotonous or atypical speech patterns; Exceptional visual or detailed memory recall.
# Response: Based on the symptoms provided, the most likely diagnosis is **Autism Spectrum Disorder (ASD)**.
#
# Here's why:
#
# * **Repetitive patterns of behavior or restricted interests:** This is a hallmark symptom of ASD, often manifesting as repetitive movements, insistence on sameness, and intense fixations on specific topics or objects.
# * **Intellectual functioning below age-expected norms:** While not all individuals with ASD have intellectual disabilities, cognitive difficulties are common.
# * **Participates in routine household tasks:**  This could indicate a desire for structure and predictability, which is common in ASD. However, it's important to note that this alone isn't diagnostic.
# * **Delayed academic performance relative to peers:** This is often seen in ASD due to difficulties with learning, social interaction, and communication.
# * **Hypersensitivity or hyposensitivity to sensory stimuli:** Sensory sensitivities are highly prevalent in ASD, with individuals experiencing either heightened or diminished responses to various sensory inputs.
# * **Verbalizes thoughts aloud to self:**  This is known as "echolalia" and is a common characteristic of ASD.
# * **Rigid insistence on specific routines involving phone use:** This demonstrates the strong need for structure and predictability often seen in ASD.
# * **Limited reciprocal social interaction:** Social communication and interaction challenges are core features of ASD.
# * **Challenges adjusting to changes in routine or environment:** This reflects the difficulty many individuals with ASD experience when faced with unexpected situations.
# * **Monotonous or atypical speech patterns:** Speech may be unusual in terms of tone, rhythm, or content, which can reflect difficulties with social communication.
# * **Exceptional visual or detailed memory recall:**  While not exclusive to ASD, strong visual memory is sometimes observed in individuals on the spectrum.
#
# **Important Note:** I am an AI chatbot and cannot provide medical diagnoses. This information is for educational purposes only. It's crucial to consult a qualified healthcare professional for a proper evaluation and diagnosis if you suspect someone may have ASD.

# %%
import csv
import os
import numpy as np
import pandas as pd
from langchain_core.documents import Document
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import OllamaLLM
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_huggingface import HuggingFaceEmbeddings

# Configuration
INPUT_ICD_PATH = '/content/icd_11_prompt_delimited.txt'
TOP5_SIMILARITY_PATH = '/content/sapbert_top5_similarity_pairs.csv'
VECTORESTORE_BASE = '/content/vectorstore'
OUTPUT_DIAGNOSES_PATH = '/content/rag_diagnoses_all_symptoms.csv'
MODEL = "gemma2:9b"  # For LLM only
SAFE_MODEL = MODEL.replace(":", "")
PERSIST_DIR = os.path.join(VECTORESTORE_BASE, f"faiss_index-sapbert-top5")
BATCH_SIZE = 50
TOP_K = 5  # Number of top matches to retrieve

# Step 1: Load original ICD data to get disorder names
def load_icd_data(file_path):
    icd_data = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter='|')
        for row in reader:
            if len(row) == 3:
                name, code, symptoms = [field.strip() for field in row]
                code = normalize_code(code)
                icd_data[code] = {'name': name, 'symptoms': symptoms}
            else:
                print(f"Skipping malformed ICD record: {row}")
    return icd_data

def normalize_code(code):
    code = re.sub(r'^\s*Disorder Code:\s*', '', code, flags=re.IGNORECASE)
    code = re.sub(r'\s+', '', code)
    return code.upper()

# Step 2: Load unique symptoms from top 5 similarity pairs
def load_unique_symptoms(file_path):
    try:
        df = pd.read_csv(file_path)
        unique_symptoms = df['User symptoms'].unique()
        print(f"Loaded {len(unique_symptoms)} unique symptom sets from {file_path}")
        return unique_symptoms
    except Exception as e:
        print(f"Error loading top 5 similarity pairs: {e}")
        raise

# Step 3: Build FAISS vectorstore with SapBERT embeddings
def build_sapbert_vectorstore():
    if os.path.exists(PERSIST_DIR):
        print(f"Vectorstore already exists at {PERSIST_DIR}. Skipping build.")
        return

    print("Building SapBERT-based vectorstore for top 5 user symptoms...")

    # Load ICD data for metadata
    icd_data = load_icd_data(INPUT_ICD_PATH)

    # Load top 5 similarity pairs
    try:
        df_top_k = pd.read_csv(TOP5_SIMILARITY_PATH)
    except Exception as e:
        print(f"Error loading top 5 similarity pairs: {e}")
        raise

    # Initialize SapBERT embeddings
    try:
        embedding_function = HuggingFaceEmbeddings(
            model_name='cambridgeltl/SapBERT-from-PubMedBERT-fulltext',
            model_kwargs={'device': 'cuda' if torch.cuda.is_available() else 'cpu'}
        )
    except Exception as e:
        print(f"Error initializing SapBERT embeddings: {e}")
        raise

    documents = []

    # Create documents
    for _, row in df_top_k.iterrows():
        user_symptoms = row['User symptoms']
        predicted_code = row['predicted ICD Code']
        predicted_symptoms = row['predicted Symptoms']
        similarity = row['Cosine Similarity']

        # Get disorder name from original ICD data
        disorder_name = icd_data.get(predicted_code, {}).get('name', 'Unknown')

        # Create document with metadata
        full_text = f"Disorder Name: {disorder_name} | Disorder Code: {predicted_code} | Disorder Symptoms: {predicted_symptoms} | User Symptoms: {user_symptoms} | Cosine Similarity: {similarity:.4f}"
        doc = Document(
            page_content=full_text,
            metadata={
                'user_symptoms': user_symptoms,
                'predicted_code': predicted_code,
                'disorder_name': disorder_name,
                'cosine_similarity': float(similarity)
            }
        )
        documents.append(doc)

    if not documents:
        print("Error: No valid records found to build vectorstore.")
        return

    print(f"Embedding {len(documents)} records...")
    try:
        # Create FAISS vectorstore
        vectorstore = FAISS.from_documents(documents, embedding_function)
        vectorstore.save_local(PERSIST_DIR)
        print(f"Vectorstore built and saved at {PERSIST_DIR}")
    except Exception as e:
        print(f"Error building vectorstore: {e}")
        raise

# Step 4: Load vectorstore and set up RAG pipeline
def setup_rag_pipeline():
    try:
        embedding_function = HuggingFaceEmbeddings(
            model_name='cambridgeltl/SapBERT-from-PubMedBERT-fulltext',
            model_kwargs={'device': 'cuda' if torch.cuda.is_available() else 'cpu'}
        )
        vectorstore = FAISS.load_local(
            PERSIST_DIR,
            embedding_function,
            allow_dangerous_deserialization=True
        )
        retriever = vectorstore.as_retriever(search_kwargs={"k": TOP_K})
    except Exception as e:
        print(f"Error loading vectorstore: {e}")
        raise

    # Initialize LLM
    try:
        llm = OllamaLLM(model=MODEL)
    except Exception as e:
        print(f"Error initializing LLM: {e}")
        raise

    # RAG prompt
    rag_prompt = ChatPromptTemplate.from_messages([
        ("system", """You are a medical diagnosis assistant. Use the provided ICD-11 context to identify the most likely diagnosis. Provide the disorder name, code, and explain why the symptoms match. If the context is insufficient, state so. Include a disclaimer that you are not a medical professional and a comprehensive evaluation by a qualified healthcare professional is needed."""),
        ("human", "Context: {context}\n\nQuestion: {question}")
    ])

    # RAG chain
    rag_chain = (
        {"context": lambda x: "\n\n".join([d.page_content for d in retriever.invoke(x["question"])]), "question": RunnablePassthrough()}
        | rag_prompt
        | llm
        | StrOutputParser()
    )
    return rag_chain

# Step 5: Process all symptoms and save diagnoses
def process_all_symptoms():
    build_sapbert_vectorstore()
    rag_chain = setup_rag_pipeline()

    # Load unique symptoms
    unique_symptoms = load_unique_symptoms(TOP5_SIMILARITY_PATH)

    # Process each symptom set and collect diagnoses
    diagnoses = []
    for query in unique_symptoms:
        try:
            response = rag_chain.invoke({"question": query})
            diagnoses.append([query, response])
            print(f"Query: {query}\nResponse: {response}\n")
        except Exception as e:
            print(f"Error processing query '{query}': {e}")
            diagnoses.append([query, f"Error: {e}"])

    # Save diagnoses to CSV
    try:
        with open(OUTPUT_DIAGNOSES_PATH, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(['Query', 'Response'])
            writer.writerows(diagnoses)
        print(f"Saved {len(diagnoses)} diagnoses to {OUTPUT_DIAGNOSES_PATH}")
    except Exception as e:
        print(f"Error saving diagnoses: {e}")

# Run the pipeline
if __name__ == "__main__":
    import torch  # Import torch for device check
    process_all_symptoms()
# Out:
# Building SapBERT-based vectorstore for top 5 user symptoms...
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name cambridgeltl/SapBERT-from-PubMedBERT-fulltext. Creating a new one with mean pooling.
# Embedding 275 records...
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name cambridgeltl/SapBERT-from-PubMedBERT-fulltext. Creating a new one with mean pooling.
# Vectorstore built and saved at /content/vectorstore/faiss_index-sapbert-top5
# Loaded 55 unique symptom sets from /content/sapbert_top5_similarity_pairs.csv
# Query: 1 scholastic backwardness cant understand money concepts behavioral concerns in social situations needs help after defecation phrasal speech need based expressive language stubbornness bites his hand if wish is not fulfilled lacks attention and concentration low sitting tolerance cant eat rice with his hands difficulty with learning new skills poor shortterm memory delayed developintellectual milestones hyperactive tendencies easily distracted poor impulse control trouble following multistep instructions limited problemsolving abilities
# Response: Based on the provided symptoms, the most likely diagnosis is **Other specified developmental speech or language disorder (6A01.Y)**.
#
# Here's why:
#
# * **Persistent Speech and Language Difficulties:** The symptoms indicate challenges with expressive language ("need-based expressive language", "phrasal speech"), comprehension ("difficulty understanding money concepts", "cant read the question fully in examination", "struggles with academic retention"), and following instructions ("trouble following multistep instructions").
# * **Impact on Functioning:**  The symptoms cause significant impairment in social situations ("behavioral concerns in social situations", "limited problemsolving abilities"), learning ("scholastic backwardness", "difficulty with learning new skills", "delayed developintellectual milestones"), and daily activities ("needs help after defecation", "cant eat rice with his hands").
# * **Other Considerations:** While some symptoms might suggest other diagnoses like Autism Spectrum Disorder (ASD) or a developmental intellectual disorder, the core presentation points more towards persistent speech and language difficulties that are not fully explained by those other categories.
#
# **Important Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This information is for educational purposes only and should not be considered a substitute for professional medical advice.  A comprehensive evaluation by a qualified healthcare professional is essential for accurate diagnosis and treatment.
#
#
#
#
# Query: 10 babbling speech hyper on medication toilet training in process makes sequel noises limited social interaction delayed verbal communication hyperactive tendencies sensory seeking behaviors difficulty with peer engagement struggles with expressive language needs structured social support restless in calm settings
# Response: Based on the provided symptoms, **Other specified developmental speech or language Disorder (6A01.Y)** appears to be the most likely diagnosis.
#
# Here's why:
#
# * **Persistent difficulties in communication:** The user describes "babbling speech," "delayed verbal communication," and "struggles with expressive language." These all point to ongoing challenges with understanding and producing language.
# * **Impairment in social communication:**  The symptoms mention "limited social interaction," "difficulty with peer engagement," and a need for "structured social support." This indicates significant difficulties using language in social contexts.
# * **Other developmental features:** The symptoms also include "hyperactive tendencies," "sensory seeking behaviors," and "restless in calm settings," which are often associated with other developmental conditions.
#
# **Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be considered a substitute for professional medical advice. It is essential to consult a qualified healthcare professional for any health concerns or before making any decisions related to your health or treatment.
#
#
#
#
# Query: 11 no ageappropriate development monosyllabic speech picky eater hyperactivity needs help after defecation aggressive when angry less sleep scared of height cant spit blow sucking etc slow information processing difficulty with complex tasks limited adaptive skills challenges in selfregulation
# Response: Based on the provided symptoms, the most likely diagnosis is **Attention deficit hyperactivity disorder (ADHD), combined presentation** (6A05.2).
#
# Here's why:
#
# * **Hyperactivity:**  The symptoms list includes "hyperactivity," "impulsive and restless," "low sitting tolerance," and "difficulty sustaining attention in uninteresting activities." These all point towards excessive motor activity and difficulty staying still, characteristic of ADHD.
# * **Inattention:** The user exhibits "slow information processing," "difficulty with complex tasks,"  "challenges in self-regulation," and "difficulty sustaining attention." This suggests problems focusing, organizing thoughts, and completing tasks - key features of inattention associated with ADHD.
# * **Combined Presentation:** The symptoms encompass both hyperactivity/impulsivity and inattention, making the "combined presentation" diagnosis most fitting.
#
# **Important Disclaimer:** I am an AI assistant and cannot provide medical advice. This analysis is based solely on the provided information and should not be considered a diagnosis. A comprehensive evaluation by a qualified healthcare professional is crucial for accurate diagnosis and treatment.
#
#
#
#
# Query: 12 no speech partial eye contact can follow some instructions sensory impairments visual auditory sleep concerns dislikes socializing aloof play doesnt chew food selfhitting limited social reciprocity sensory processing difficulties delayed verbal communication repetitive selfstimulatory behaviors
# Response: Based on the symptoms provided, **Autism Spectrum Disorder (ASD)** is a strong possibility.
#
# Here's why:
#
# * **Social Communication and Interaction:**
#     * "no speech" -  Delayed or absent speech is common in ASD.
#     * "partial eye contact" - Difficulty with eye contact is frequent in ASD.
#     * "limited social reciprocity" - Lack of back-and-forth conversation and difficulty understanding social cues are hallmark features.
#     * "difficulty sustaining conversations"
#     * "difficulty understanding indirect/nonverbal cues"
#     * "poor social reasoning"
#     * "challenges in adaptive social behaviors"
#
# * **Restricted, Repetitive Patterns of Behavior:**
#     *  "repetitive self-stimulatory behaviors" - This could include rocking, hand flapping, or other repetitive movements.
#     * "sensory processing difficulties" - Sensory sensitivities are common in ASD. Visual and auditory impairments mentioned could be related to this.
#
# * **Other Symptoms:**
#     * "sleep concerns", "dislikes socializing", "aloof play", "doesnt chew food", "self-hitting"  - These can all be associated with ASD, though they aren't exclusive to it.
#
#
# **Important Note:** While these symptoms strongly suggest ASD, a diagnosis can only be made by a qualified professional after a thorough evaluation.
#
# **Next Steps:** If you are concerned about your child, please reach out to their pediatrician or a developmental specialist. They can conduct an assessment and provide guidance on appropriate support and interventions.
#
# Query: 13 scholastic backwardness lacks attention and concentration needs to get instructions repeated sibling rivalry cant follow 2 steps instruction stubborn throws tantrums inferior nature cant wear socks on her own cant button limited intellectual flexibility poor selfregulation difficulty with fine motor skills challenges in social interactions
# Response: Based on the provided symptoms, **Disorder of intellectual development, severe (6A00.2)** seems to be the most likely diagnosis.
#
# Here's why:
#
# * **Scholastic backwardness:**  Indicates difficulties in learning and academic performance, consistent with intellectual developmental disorders.
# * **Attention and concentration issues:** A common feature of these disorders.
# * **Difficulty following instructions:** Implies challenges with cognitive processing and executive function, often seen in intellectual developmental disorders.
# * **Sibling rivalry, stubbornness, tantrums:**  Behavioral problems can be associated with frustration stemming from learning difficulties.
# * **Limited intellectual flexibility:** Suggests rigid thinking patterns and difficulty adapting to changes, characteristic of some intellectual disabilities.
# * **Poor self-regulation:**  Struggles with controlling impulses and emotions, frequently seen in these disorders.
# * **Fine motor skill challenges:**  Can be a symptom of developmental delays affecting coordination and movement.
# * **Challenges in social interactions:** Difficulty understanding social cues and navigating relationships can result from cognitive impairments.
#
# **Important Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This analysis is based solely on the information provided and should not be considered a substitute for professional evaluation.
#
# A comprehensive assessment by a qualified healthcare professional, including standardized testing and clinical observation, is necessary to arrive at an accurate diagnosis and develop an appropriate treatment plan.
#
#
#
#
# Query: 14 one word speech limited vocabulary aloof play hyper partial eye contact toilet training in process restricted behaviors few selftalking while playing selfstimulating behaviors sensorial impairments obsessed about pink colour doll etc less adaptations limited social reciprocity sensory processing issues delayed verbal communication repetitive behaviors
# Response: Based on the provided symptoms, **Other specified developmental speech or language Disorder (6A01.Y)** is the most likely diagnosis.
#
# Here's why:
#
# * **Persistent difficulties in speech and language:** The user describes "14 one word speech," "limited vocabulary," and "delayed verbal communication."
# * **Impairment in social communication:** Symptoms like "aloof play," "partial eye contact," "limited social reciprocity," and "less adaptations" point to challenges in social interactions.
# * **Restricted, repetitive behaviors:**  The user mentions "restricted behaviors," "few self-talking while playing," "self-stimulating behaviors," and "repetitive behaviors."
# * **Sensory processing issues:** The description includes "sensorial impairments" and "sensory processing issues."
#
# These symptoms align closely with the criteria for Other specified developmental speech or language Disorder, as it encompasses persistent difficulties in communication that are not fully explained by other disorders.
#
#
# **Disclaimer:** I am an AI assistant and cannot provide medical advice. This information is for general knowledge purposes only and should not be substituted for a comprehensive evaluation by a qualified healthcare professional.
#
#
# Query: 15 no social conformity gets scared easily in social settings lacks confidence in social settings stranger anxiety in social groups between conversations she suddenly upbrings irrelevant topics talks with high pitch lacks social etiquettes has difficulty sustaining conversations difficulty understanding indirectnonverbal cues unable to manage fightsdifference of opinions no age appropriate maturity in social settings poor social reasoning limited social reciprocity challenges in adaptive social behaviors difficulty with perspectivetaking
# Response: Based on the provided context and symptoms, the most likely diagnosis is **Other specified developmental speech or language Disorder (6A01.Y)**.
#
# Here's why:
#
# * **Persistent Difficulties:** The user describes ongoing issues with communication, understanding social cues, and engaging appropriately in social situations.
# * **Developmental Onset:** The symptoms are described as present since the individual's developmental period.
# * **Significant Impairment:** The symptoms clearly cause difficulties in various areas of functioning, including social interaction, education, and daily life.
#
# The user's specific symptoms like "no social conformity," "stranger anxiety," "difficulty understanding indirect nonverbal cues," "unable to manage fights/difference of opinions," and "poor social reasoning" all point towards significant challenges in social communication and interaction, aligning with the criteria for Other Specified Developmental Speech or Language Disorder.
#
# **Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be considered a substitute for professional medical advice. A comprehensive evaluation by a qualified healthcare professional is crucial for accurate diagnosis and treatment.
#
#
#
#
# Query: 16 scholastic backwardness speaks fast epilepsy silent seizures hyper gets excited easily low sitting tolerance restless no proper pencil grips impulsive behaviors difficulty sustaining attention overactive motor skills challenges in fine motor coordination struggles with task persistence heightened emotional reactivity needs structured routines
# Response: Based on the provided information, the most likely diagnosis is **Other specified body-focused repetitive behaviour (6B25.Y)**.
#
# **Here's why:**
#
# * **Recurrent habitual actions:** The user symptoms mention "no proper pencil grips" and "restless," which could indicate repeated, habitual actions directed at the integument. While not explicitly stated, these behaviors might be biting or chewing on pencils or other objects.
# * **Unsuccessful attempts to stop:**  The user's struggles with focus, task persistence, and impulsive behaviors suggest difficulty controlling these actions.
# * **Significant distress or impairment:** The extensive list of symptoms impacting academic performance ("scholastic backwardness"), social interactions ("needs structured routines"), and daily functioning ("difficulty sustaining attention", "overactive motor skills") indicates significant distress and impairment.
#
# **Important Disclaimer:** I am an AI chatbot and cannot provide medical advice. This information is for educational purposes only and should not be considered a substitute for professional medical evaluation.
#
#
# It's crucial for the user to consult a qualified healthcare professional for a comprehensive assessment and diagnosis. They can properly evaluate the symptoms, rule out other conditions, and recommend appropriate treatment options.
#
# Query: 17 sensorial sensitivities auditory limited socializing phrasal speech need based partial eye contact self stimulating behaviors delayed verbal communication limited social engagement sensory processing issues repetitive behaviors difficulty with social reciprocity
# Response: Based on the provided symptoms, the most likely diagnosis is **Other specified developmental speech or language disorder (6A01.Y)**.
#
# Here's why:
#
# * **Persistent difficulties in understanding or producing speech and language:**  The symptoms mention "phrasal speech," "delayed verbal communication," and difficulty with social reciprocity, all pointing towards challenges with language development and use.
# * **Significant impairment in social communication:** Limited socializing, partial eye contact, and difficulty with social reciprocity strongly suggest impairments in social communication skills, a hallmark of developmental speech or language disorders.
# * **Sensory processing issues:** The mention of "sensorial sensitivities" and "sensory processing issues" further aligns with this diagnosis, as sensory processing difficulties are often associated with developmental disorders.
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical advice. This information is for general knowledge purposes only and should not be considered a substitute for professional medical evaluation. A comprehensive assessment by a qualified healthcare professional is essential for accurate diagnosis and treatment.
#
#
#
#
# Query: 18 no ageappropriate development no speech partial eye contact limited name calling response sensorial concerns hyperactivity and impulsive no fear of danger restless toilet training is not attained stubborn bangs head and screams a lot insensitive to pain scared of animals cat goat selfstimulating emotions repetitive behaviors limited social reciprocity delayed verbal communication sensory processing difficulties
# Response: The symptoms you describe strongly suggest **Autism Spectrum Disorder (ASD)**.
#
# Here's why these symptoms align with ASD:
#
# * **No age-appropriate development:** This is a hallmark of ASD, where developmental milestones are significantly delayed or absent.
#
# * **No speech or limited verbal communication:**  Many individuals with ASD experience delays in speech and language development. Some may be non-verbal.
# * **Partial eye contact:** Difficulty with maintaining eye contact is common in ASD.
#
# * **Limited name calling response:** This suggests challenges with social interaction and understanding personal names.
# * **Sensorial concerns:** Sensory sensitivities (over or under-reactivity) are frequent in ASD.  This can manifest as discomfort with certain textures, sounds, lights, etc.
# * **Hyperactivity and impulsivity:** While not all autistic individuals are hyperactive, many exhibit restlessness, difficulty focusing, and impulsive behaviors.
#
# * **No fear of danger:** This can be a sign of difficulties with understanding risk and potential harm.
#
# * **Restless toilet training difficulties:**  Developmental delays can affect various areas, including toileting.
# * **Stubbornness, banging head, screaming:** These are common ways autistic individuals express frustration or discomfort when struggling to communicate their needs.
#
# * **Insensitive to pain:** Some individuals with ASD have differences in pain perception.
#
# * **Scared of animals:** Specific fears or anxieties can be more prevalent in ASD.
# * **Self-stimulating emotions:** Repetitive behaviors and self-soothing actions are common coping mechanisms for autistic individuals.
#
# * **Limited social reciprocity:**  Challenges understanding social cues, engaging in back-and-forth interactions, and forming relationships are core features of ASD.
#
#
# **Important Note:** I am an AI and cannot provide diagnoses. It's crucial to consult a qualified healthcare professional, such as a pediatrician or developmental specialist, for a proper evaluation and diagnosis. They can assess your child's specific needs and recommend appropriate interventions and support.
#
#
# Query: 19 no ageappropriate development delayed speech repeats words when he doesnt comprehend limited vocabulary unclear speech hyperactivity hyposensitive pencil grip limited attention span slow information processing difficulty with complex tasks challenges in verbal comprehension struggles with sustained attention
# Response: Based on the provided symptoms, the most likely diagnosis is **Other specified developmental speech or language disorder (6A01.Y)**.
#
# **Here's why:**
#
# * **Persistent Difficulties:** The user describes several persistent difficulties with speech and language, including delayed speech, repetition of words when not understanding, limited vocabulary, unclear speech, and struggles with verbal comprehension.
# * **Developmental Onset:** The symptoms indicate a lack of age-appropriate development, suggesting the onset occurred during the developmental period.
# * **Significant Impairment:**  The listed symptoms ("limited attention span," "slow information processing," "difficulty with complex tasks," "struggles with sustained attention") suggest significant impairment in communication and daily functioning.
# * **Exclusion of Other Disorders:** The context states that these difficulties are not better accounted for by other developmental disorders like autism spectrum disorder, intellectual development disorder, or sensory impairments.
#
# **Important Disclaimer:**
#
# I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is essential for an accurate diagnosis and treatment plan.
#
#
#
#
# Query: 2 scholastic backwardness delayed reading skills difficulty with writing tasks minimal shortterm memory issues struggles with academic retention slow processing of new information challenges in academic comprehension needs repeated instructions
# Response: Based on the provided symptoms, **Developmental learning Disorder with impairment in reading (6A03.0)** is the most likely diagnosis.
#
# Here's why:
#
# * **Scholastic backwardness:** This indicates a significant lag in academic performance compared to peers of the same age.
# * **Delayed reading skills:**  This directly points towards a difficulty learning and using reading skills.
# * **Difficulty with writing tasks:** Writing relies heavily on reading comprehension and processing information, both areas affected by this disorder.
# * **Minimal short-term memory issues, struggles with academic retention:** These suggest difficulties in retaining and recalling information learned, crucial for academic success.
# * **Slow processing of new information, challenges in academic comprehension:**  These symptoms highlight the core issue of difficulty understanding and learning new material.
# * **Needs repeated instructions:** This indicates a persistent struggle to grasp concepts on the first attempt.
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical advice. This information is for general knowledge purposes only and should not be substituted for a comprehensive evaluation by a qualified healthcare professional.  A proper diagnosis requires a thorough assessment by a doctor or specialist.
#
#
#
#
# Query: 20 aloof play lacks expressive speech unclear speech echolalia self stimulating emotions situational limited social engagement delayed verbal communication repetitive behaviors sensory seeking tendencies difficulty with social reciprocity
# Response: Based on the provided symptoms, the most likely diagnosis is **Other specified developmental speech or language disorder (6A01.Y)**.
#
# Here's why:
#
# * **Persistent difficulties in communication:** The symptoms clearly indicate challenges with understanding and producing speech ("lacks expressive speech", "unclear speech", "delayed verbal communication").
# * **Social communication impairment:**  "Aloof play", "limited social engagement", "difficulty with social reciprocity" all point to struggles in using language for social interaction.
# * **Repetitive behaviors and sensory seeking:** These are common features associated with developmental disorders, including other specified developmental speech or language disorder.
#
# The other options, while sharing some similarities, don't fit as well:
#
# * **Autism spectrum disorder (6A02.3):** While the symptoms overlap, the emphasis on "marked impairment in functional language" and limitations in using words for instrumental purposes are not explicitly mentioned in the user's description.
# * **Developmental speech or language disorder (6A01.Z):**  This is similar to the most likely diagnosis but lacks the specificity of "other specified" which allows for a broader range of symptoms.
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
#
#
# Query: 21 speech delay scholastic backwardness downs syndrome delayed verbal communication challenges in academic progress limited socioadaptive skills difficulty with expressive language struggles with social interactions
# Response: Based on the provided symptoms, **Disorder of intellectual development, severe (6A00.2)** seems most likely.
#
# Here's why:
#
# * **"Scholastic backwardness," "challenges in academic progress," and "difficulty with expressive language"** all point towards difficulties with learning and communication, which are hallmark features of intellectual developmental disorders.
# * **"Speech delay," "delayed verbal communication," and "struggles with social interactions"** further support this diagnosis as these are common co-occurring symptoms with intellectual disabilities.
# * **"Downs syndrome"** explicitly mentions a genetic condition that often presents with intellectual disability.
# * **"Limited socioadaptive skills"**  indicates challenges in adapting to social situations and routines, another characteristic of intellectual developmental disorders.
#
# **Important Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This analysis is based solely on the information provided and should not be considered a substitute for professional medical evaluation. A comprehensive assessment by a qualified healthcare professional is crucial for an accurate diagnosis and appropriate treatment plan.
#
#
#
#
# Query: 22 one word speech no expressive language robotic speech partial eye contact hyper to some extent toilet training not attained yet restricted behaviors few limited social reciprocity delayed verbal communication repetitive behaviors challenges in social engagement
# Response: Based on the provided symptoms, the most likely diagnosis is **Autism spectrum disorder without disorder of intellectual development and with impaired functional language (6A02.2)**.
#
# Here's why:
#
# * **"One word speech, no expressive language, robotic speech"**: This points to significant difficulties with communication, a hallmark feature of autism spectrum disorder.
# * **"Partial eye contact, hyper to some extent"**:  While not universal in autism, atypical social interaction patterns like limited or unusual eye contact are common.
# * **"Toilet training not attained yet, restricted behaviors, few limited social reciprocity, delayed verbal communication, repetitive behaviors, challenges in social engagement"**: These symptoms further support the diagnosis of autism spectrum disorder as they align with the core difficulties in social interaction, communication, and repetitive behaviors characteristic of the condition.
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. The information provided above is for general knowledge purposes only and should not be considered a substitute for professional medical advice. It is essential to consult with a qualified healthcare professional for any health concerns or before making any decisions related to your health or treatment.
#
#
#
#
# Query: 23 scholastic backwardness cant understand money concepts disturbs others in class hits others low sitting tolerance doesnt comply to instruction limited intellectual flexibility difficulty with impulse control challenges in following directions poor social skills
# Response: Based on the provided symptoms, **Disorder of intellectual development, mild (6A00.0)** seems most likely.
#
# Here's why:
#
# * **Scholastic backwardness:** This indicates difficulties in learning and academic performance, common in intellectual developmental disorders.
# * **Difficulty understanding money concepts:**  This points to challenges with abstract thinking and complex financial reasoning, often seen in milder intellectual disabilities.
# * **Behavioral issues (disturbing others, hitting, low sitting tolerance, noncompliance):** These behaviors can be associated with impulsivity and difficulty regulating emotions, which are also common features of intellectual developmental disorders.
# * **Limited intellectual flexibility and poor impulse control:** These directly relate to difficulties in cognitive functioning and executive skills, characteristic of intellectual disabilities.
# * **Challenges following directions and poor social skills:** These suggest impairments in communication, understanding social cues, and interacting appropriately with others, further supporting an intellectual disability diagnosis.
#
# **Important Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. The information provided is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or psychologist is necessary for an accurate diagnosis and appropriate treatment plan.
#
#
#
#
# Query: 24 scholastic backwardness forgets whatever is taught difficulty in remembering alphabets unclear speech stubborn hits and screams when angry picky eater challenges in academic retention slow processing speed difficulty with phonological awareness poor selfregulation
# Response: Based on the provided information, **Disorder of intellectual development, severe (6A00.2)** appears to be the most likely diagnosis.
#
# Here's why:
#
# * **Scholastic backwardness:** This indicates difficulties in learning and academic performance, consistent with intellectual developmental disorders.
# * **Difficulty remembering alphabets:**  This points towards problems with learning and memory, common in intellectual developmental disorders.
# * **Unclear speech:** Speech difficulties are frequently associated with intellectual developmental disorders.
# * **Stubbornness, hitting, screaming:** These behavioral issues can be present in children struggling with intellectual development as they may have difficulty understanding social expectations and regulating their emotions.
# * **Picky eating:**  This is often seen in individuals with intellectual developmental disorders due to sensory sensitivities or difficulties with mealtime routines.
# * **Academic retention challenges, slow processing speed, phonological awareness difficulty:** These all directly relate to learning and cognitive function deficits characteristic of intellectual developmental disorders.
# * **Poor self-regulation:** This suggests an inability to manage emotions and behaviors effectively, a common feature in individuals with intellectual developmental disorders.
#
# **Important Disclaimer:** I am not a medical professional. This information is for educational purposes only and should not be considered medical advice. A comprehensive evaluation by a qualified healthcare professional is essential for accurate diagnosis and treatment.
#
#
#
#
# Query: 25 delayed speech monosyllabic speech unclear hyper lacks patience limited attention and concentration stubborn toilet training is not attained selfhitting when angry doesnt express his needs constant singing and humming rhymes limited social reciprocity delayed developintellectual milestones challenges in verbal communication impulsive behaviors
# Response: Based on the provided context and symptoms, the most likely diagnosis is **Autism spectrum disorder without intellectual disability and with impaired functional language (6A02.2)**.
#
# Here's why:
#
# * **Marked impairment in functional language:** The user describes delayed speech, monosyllabic speech, unclear speech, and difficulty expressing needs. This aligns with the diagnostic criteria for 6A02.2 which requires "marked impairment in functional language" where the individual can't use more than single words or simple phrases for instrumental purposes.
# * **Other symptoms:**  Many of the listed symptoms (hyperactivity, lack of patience, limited attention and concentration, stubbornness, toilet training issues, self-hitting, limited social reciprocity, delayed developmental milestones, impulsive behaviors) are commonly associated with Autism Spectrum Disorder.
#
# **Important Disclaimer:** I am not a medical professional. This information is for educational purposes only and should not be considered medical advice. A comprehensive evaluation by a qualified healthcare professional is necessary for an accurate diagnosis and treatment plan.
#
#
#
#
# Query: 26 repetitive and restricted behaviors self talking less of expressive language hyper toilet training not attained low sitting tolerance unclear speech obsessed about reading and books doesnt eat rice plaincurry rice but eats biryani limited social engagement delayed verbal communication sensory seeking behaviors difficulty with social reciprocity
# Response: Based on the provided symptoms and considering the ICD-11 context, **Autism spectrum disorder without disorder of intellectual development and with impaired functional language (6A02.2)** seems like the most likely diagnosis.
#
# Here's why:
#
# * **Repetitive and restricted behaviors:** This is a core feature of autism spectrum disorder.
# * **Self-talk and limited expressive language:** The description of "less expressive language" and difficulty communicating needs points towards impaired functional language, which aligns with the ICD-11 criteria for 6A02.2.
# * **Delayed verbal communication and social reciprocity difficulties:** These are also hallmark signs of autism spectrum disorder.
# * **Sensory seeking behaviors:**  Sensory sensitivities are common in individuals with autism.
#
# **Important Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
#
#
# Query: 27 unclear speech no age appropriate maturity needs help while cleaning after toilet use right lower limb is affected cp limited intellectual flexibility delayed adaptive skills challenges in verbal communication difficulty with motor coordination
# Response: Based on the provided symptoms and ICD-11 context, **Autism Spectrum Disorder without Intellectual Disability and with Impaired Functional Language (6A02.2)** seems most likely.
#
# Here's why:
#
# * **Unclear Speech & Challenges in Verbal Communication:** This directly aligns with the disorder's criteria of marked impairment in functional language.
# * **Limited Intellectual Flexibility & Delayed Adaptive Skills:** These point towards difficulties beyond typical developmental milestones, suggesting a neurodevelopmental condition like Autism Spectrum Disorder.
# * **Difficulty with Motor Coordination:** While not exclusive to Autism Spectrum Disorder, it can be a co-occurring feature.
#
# **Important Disclaimer:** I am an AI and cannot provide medical diagnoses. This analysis is based on the limited information provided and should not be substituted for a comprehensive evaluation by a qualified healthcare professional.
#
#
#
#
# Query: 28 one word speech no age appropriate intelligence hyper stubborn cant delay gratification low sitting tolerance hits others delayed verbal communication impulsive behaviors limited attention span difficulty with social interactions
# Response: Based on the provided context and symptoms, **Attention Deficit Hyperactivity Disorder, combined presentation (6A05.2)** appears to be the most likely diagnosis.
#
# Here's why:
#
# * **Symptoms Match:** The user-provided symptoms strongly align with the diagnostic criteria for ADHD, combined presentation.  Key indicators include:
#     * Hyperactive behaviors: "hyper restless, low sitting tolerance, hits others"
#     * Impulsive behaviors: "cant delay gratification," "hits others," "talks fast"
#     * Inattentive behaviors: "difficulty sustaining attention," "limited attention span"
#     * Social interaction challenges: "difficulty with social interactions"
#
# * **Cosine Similarity:** The high cosine similarity (0.6948) between the user symptoms and the ADHD, combined presentation description further supports this diagnosis.
#
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or mental health expert is necessary for an accurate diagnosis and treatment plan.
#
#
# Query: 29 no age appropriate intelligence plays aloof stubborn hits others when angry self hitting when angry too much of screen time echolalia needs help after defecation limited social reciprocity delayed verbal communication challenges in adaptive behaviors poor selfregulation
# Response: Based on the provided context and symptoms, the most likely diagnosis is **Autism spectrum disorder with intellectual developmental disorder and impaired functional language (6A02.3)**.
#
# Here's why:
#
# * **Persistent difficulties in social communication and interaction:** The symptoms indicate limited social reciprocity, aloof play, difficulty adapting to change, and challenges relating to emotions.
# * **Restricted, repetitive patterns of behavior, interests, or activities:**  The description includes echolalia, self-hitting when angry, hyperactivity, repetitive play patterns, and a preference for screen time.
# * **Impaired functional language:** Delayed verbal communication and difficulties expressing needs are mentioned.
#
# **Important Note:** I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional.  A comprehensive evaluation by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
#
#
# Query: 3 scholastic backwardness less sleep has performance anxiety stammers mishears few sounds misspells avoids study time difficulty with reading fluency challenges in writing accuracy struggles with phonological processing slow academic progress needs structured learning support anxiety in academic settings poor spelling retention
# Response: Based on the provided symptoms and ICD-11 context, the most likely diagnosis is **Developmental learning disorder with impairment in reading (6A03.0)**.
#
# Here's why:
#
# * **Significant difficulties in reading:** The user exhibits "difficulty with reading fluency," "challenges in writing accuracy," "struggles with phonological processing," and "poor spelling retention." These all directly point to reading-related learning challenges.
# * **Academic impact:**  Symptoms like "scholastic backwardness," "slow academic progress," and "needs structured learning support" indicate the reading difficulties significantly affect academic performance.
# * **Exclusion criteria:** The context states that this disorder is *not* due to intellectual disabilities, sensory impairments, neurological disorders, lack of education, or psychosocial adversity.  While we don't have all medical history, the presented symptoms don't immediately suggest these alternative causes.
#
# **Important Disclaimer:** I am an AI and cannot provide medical diagnoses. This information is for informational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
#
#
# Query: 30 scholastic backwardness getting angry quickly stubborn not interested in studies impulsive and restless low sitting tolerance careless about his things sustained attention in interested activities only writes slow difficulty sustaining attention hyperactive tendencies poor impulse control challenges in academic engagement
# Response: Based on the provided symptoms, the most likely diagnosis is **Attention deficit hyperactivity disorder, combined presentation (6A05.2)**.
#
# Here's why:
#
# * **Combined Presentation:** The user exhibits both inattentive and hyperactive-impulsive symptoms.  The symptoms of "difficulty sustaining attention," "careless about his things," "slow writing," and "challenges in academic engagement" point towards inattention. Conversely, "impulsive and restless," "low sitting tolerance," "hyperactive tendencies," and "poor impulse control" suggest hyperactivity-impulsivity.
#
# * **Significant Impact:**  The symptoms significantly interfere with his scholastic performance ("scholastic backwardness") and overall functioning.
#
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical advice. This information is for general knowledge purposes only and should not be considered a substitute for professional medical evaluation. It is essential to consult with a qualified healthcare professional for any health concerns or before making any decisions related to your health or treatment.
#
#
# Query: 31 scholastic backwardness delayed academic progress difficulty with intellectual tasks limited problemsolving skills slow learning pace challenges in retaining information needs structured academic support struggles with complex concepts
# Response: Based on the provided context and symptoms, **Disorder of intellectual development, moderate (6A00.1)** seems most likely.
#
# Here's why:
#
# * **"Scholastic backwardness," "delayed academic progress," "difficulty with intellectual tasks," "limited problem-solving skills," "slow learning pace," "challenges in retaining information," and "struggles with complex concepts"** all point to significant difficulties in acquiring and applying knowledge, which is a core feature of disorders of intellectual development.
# * The description of **"needs structured academic support"**  further aligns with the moderate severity level, where individuals require additional assistance to learn and progress.
#
# **Important Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is crucial for an accurate diagnosis and personalized treatment plan.
#
#
#
#
# Query: 32 scholastic backwardness lacks attention and concentration has difficulty with remembering things for longer run in academics needs to get instructions repeated slow responsiveness slow processing speed challenges in academic retention difficulty with sustained attention needs structured learning support
# Response: Based on the provided context and symptoms, **Disorder of intellectual development, moderate (6A00.1)** seems like the most likely diagnosis.
#
# Here's why:
#
# * **Scholastic backwardness:**  The description indicates significant difficulty in academics, aligning with the core feature of intellectual functioning below average in this disorder.
# * **Attention and concentration difficulties:** The user reports struggles with focus and sustained attention, which are common challenges associated with moderate intellectual developmental disorders.
# * **Memory problems:** Difficulty remembering things for longer periods is another symptom consistent with this diagnosis.
# * **Slow responsiveness and processing speed:** These traits align with the characteristic of slower cognitive processing often seen in individuals with intellectual developmental disorders.
# * **Need for structured learning support:** The requirement for structured learning reflects the need for additional support and tailored approaches common in these conditions.
#
# **Important Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This analysis is based on the provided information and should not be considered a substitute for a comprehensive evaluation by a qualified healthcare professional.
#
#
#
#
# Query: 33 hyper restless lacks patience toilet training not attained low sitting tolerance stubborn self hitting behaviors unclear speech talks need based very moody doesnt like when people give instructions impulsive behaviors limited intellectual flexibility difficulty with verbal communication poor selfregulation
# Response: Based on the provided context and symptoms, **Attention Deficit Hyperactivity Disorder, combined presentation (6A05.2)** seems most likely.
#
# Here's why:
#
# * **Combined Presentation:** The user's symptoms clearly indicate both inattentive and hyperactive-impulsive traits. They describe difficulties with sustained attention, organization, distractibility, restlessness, impulsivity, and difficulty following instructions (inattentive).  Simultaneously, they exhibit excessive motor activity, lack of patience, and acting without considering consequences (hyperactive-impulsive).
#
# * **Symptom Match:** Many symptoms align directly with the disorder description: hyperactivity, restlessness, difficulty sitting still, impatience, stubbornness, self-hitting behaviors, unclear speech, impulsivity, poor self-regulation.
#
# **Important Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for a comprehensive evaluation by a qualified healthcare professional.  A doctor can properly assess the individual's symptoms, history, and conduct necessary tests to arrive at an accurate diagnosis and recommend appropriate treatment.
#
#
#
#
# Query: 34 scholastic backwardness lacks attention and concentration low sitting tolerance cant delay gratification avoids writing task hyper stubborn hits others impulsive behaviors difficulty sustaining attention challenges in academic engagement poor impulse control
# Response: Based on the provided context and symptoms, the most likely diagnosis is **Disorder of intellectual development, severe (6A00.2)**.
#
# Here's why:
#
# * **Significant Intellectual Deficits:** The user describes "scholastic backwardness" and "challenges in academic engagement," indicating difficulties with learning and academic performance consistent with a disorder of intellectual development.
# * **Adaptive Behavior Issues:** Symptoms like "low sitting tolerance," "can't delay gratification," "hyper stubborn," "hits others," "impulsive behaviors," and "poor impulse control" suggest challenges with adaptive behavior, which is a key feature of this disorder.
#
# The symptoms align closely with the description of severe intellectual development in the provided ICD-11 context, particularly those related to:
#
# * **Limited Language and Academic Skills:**  Though not explicitly stated, the academic struggles suggest potential limitations in language acquisition and academic skill development.
# * **Motor Impairments:** While not mentioned directly, some symptoms like "difficulty with fine motor skills" could indicate underlying motor challenges.
# * **Need for Structured Support:** The need for "structured learning support" points towards the individual's dependence on external structure and guidance, which is common in severe intellectual development.
#
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical advice. This information is for general knowledge purposes only and should not be substituted for the evaluation of a qualified healthcare professional. A comprehensive assessment by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
# Query: 35 scholastic backwardness lacks patience needs immediate gratification hyper low sitting tolerance excessive talking irrelevant talks cant follow 2 steps instructions unclear speech lacks attention and concentration impulsive behaviors difficulty sustaining attention delayed verbal communication poor selfregulation
# Response: Based on the provided symptoms, the most likely diagnosis is **Other specified developmental speech or language Disorder (6A01.Y)**.
#
# **Here's why:**
#
# * **Persistent Difficulties:** The user describes challenges with understanding and producing speech, following instructions, and using language appropriately in social contexts. These difficulties are described as persistent.
# ...
#
# * **Cosine Similarity:** The high cosine similarity score (0.6948) between the user's symptoms and the description of ADHD, combined presentation further supports this diagnosis.
#
#
# **Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This information is for general knowledge purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or other licensed clinician is necessary for an accurate diagnosis and treatment plan.
#
#
# Query: 51 no ageappropriate development delayed speech one wordlimited vocab needs help in cleaning after defecation needs help in adls no parallel play aloof play doesnt chew well especially rice cant spitsuck doesnt brush scared of height limited intellectual flexibility delayed verbal communication challenges in adaptive behaviors difficulty with motor coordination
# Response: Based on the provided symptoms, the most likely diagnosis is **Other specified developmental speech or language disorder (6A01.Y)**.
#
# Here's why:
#
# * **Persistent difficulties in understanding or producing speech or language:**  The symptoms clearly indicate delayed speech, limited vocabulary, and difficulty with verbal communication.
# * **Markedly below expected abilities for age:** The mention of "no age-appropriate development" and "delayed speech" strongly suggests the individual's language skills are significantly behind their peers.
# * **Significant impairment in social communication or other areas of functioning:**  Symptoms like "aloof play," difficulty with parallel play, and struggles with adaptive behaviors (like cleaning after defecation and ADLs) point to a significant impact on social interaction and daily life.
#
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
# Query: 52 scholastic backwardness unclear speech forgetting things easily has difficulty remembering concepts sensitive natured regressed in academic copy writing skills lacks attention and concentration has inquisitive questions and excessive talking syndromic features challenges in academic retention difficulty sustaining attention slow processing speed delayed verbal communication
# Response: Based on the provided symptoms, **Other specified developmental speech or language Disorder (6A01.Y)** is the most likely diagnosis.
#
# Here's why:
#
# * **Persistent difficulties in understanding or producing speech and/or language:**  The user reports "unclear speech", "delayed verbal communication", and challenges with academic writing.
# * **Impairment in social communication:** The symptoms suggest difficulty remembering concepts, expressing oneself clearly, and sustaining attention during conversations. This can lead to social isolation and struggles with peer interactions.
# * **Academic difficulties:**  "Scholastic backwardness", challenges with academic retention, and regressed copywriting skills point towards significant learning impairments.
#
# **Important Disclaimer:** I am not a medical professional. This information is for educational purposes only and should not be considered a diagnosis or treatment recommendation. A comprehensive evaluation by a qualified healthcare professional is crucial for accurate diagnosis and personalized treatment.
#
#
#
#
# Query: 53 no ageappropriate development speech delay limited eye contact limited name calling response few sensorial concerns hyper repetitive and restricted play patterns able to relate to emotions photogenic memory enjoys music limited social reciprocity delayed verbal communication sensory processing issues hyperactive tendencies
# Response: Based on the provided symptoms and ICD-11 context, the most likely diagnosis is **Autism spectrum disorder without disorder of intellectual development and with impaired functional language (6A02.2)**.
#
# Here's why:
#
# * **Marked impairment in functional language:** The user mentions "delayed verbal communication" and "speech delay," indicating difficulties using language effectively for communication.
# * **Autism Spectrum Disorder features:** The symptoms align with ASD criteria, including limited eye contact, limited social reciprocity, repetitive and restricted play patterns, and challenges relating to emotions.
#
# **Important Considerations:**
#
# The context provided is helpful but may not be comprehensive enough for a definitive diagnosis.
#
# **Disclaimer:** I am an AI assistant and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
# Query: 54 scholastic backwardness unacceptable behaviors in class lacks patience needs immediate gratification hyper low sitting tolerance excessive talking irrelevant talks cant follow 2 steps instructions whenever she is upset she lies down on the floor even in school impulsive behaviors difficulty sustaining attention poor impulse control challenges in classroom behavior
# Response: Based on the provided symptoms and ICD-11 context, the most likely diagnosis is **Attention deficit hyperactivity disorder, predominantly inattentive presentation (6A05.0)**.
#
# Here's why:
#
# * **Predominantly Inattentive Symptoms:** The user's symptoms clearly highlight difficulties with sustained attention, distractibility, organization, and following instructions.  These are key characteristics of inattention, as defined in the ICD-11 description for this disorder.
# * **Some Hyperactive-Impulsive Symptoms:** While the symptoms primarily point to inattention, there are also mentions of "impulsive behaviors," "difficulty sustaining attention," and challenges with classroom behavior. These could suggest some hyperactive-impulsive traits, but they are not the dominant feature.
#
# **Other Considerations:**
#
# * **Cosine Similarity:** The higher cosine similarity scores for  "Attention deficit hyperactivity disorder, predominantly inattentive presentation" and "Attention deficit hyperactivity disorder, combined presentation" further support this diagnosis.
# * **Exclusion of Other Disorders:** It's important to note that the symptoms could potentially overlap with other disorders. A comprehensive evaluation by a qualified healthcare professional is crucial to rule out other possibilities and make an accurate diagnosis.
#
#
# **Disclaimer:** I am not a medical professional. This information is for educational purposes only and should not be considered medical advice. Always consult with a qualified healthcare provider for diagnosis and treatment.
#
#
# Query: 55 no ageappropriate development monosyllabic speech picky eater hyperactivity needs help after defecation aggressive when angry less sleep scared of height cant spit blow sucking etc limited intellectual flexibility delayed verbal communication challenges in adaptive behaviors poor selfregulation
# Response: Based on the provided symptoms, **Autism Spectrum Disorder with Intellectual Disability (6A02.3)** appears to be the most likely diagnosis.
#
# Here's why:
#
# * **Developmental Delay:** The user mentions "no age-appropriate development," indicating a significant delay in overall development.
# * **Language Impairment:**  "Monosyllabic speech," "delayed verbal communication," and "limited intellectual flexibility" strongly suggest a marked impairment in language development and comprehension.
# * **Social Communication Challenges:** Phrases like "limited social reciprocity" and "poor self-regulation" point towards difficulties in interacting with others and managing emotions, which are core features of autism.
# * **Repetitive Behaviors:**  "Constant singing and humming rhymes" and the mention of repetitive actions (e.g., sucking) are common in autistic individuals.
#
# **Important Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. The information provided is for educational purposes only and should not be substituted for a comprehensive evaluation by a qualified healthcare professional.
#
#
#
#
# Query: 6 scholastic backwardness speaks fast epilepsy silent seizures hyper gets excited easily low sitting tolerance restless no proper pencil grips impulsive behaviors difficulty sustaining attention overactive motor skills challenges in fine motor coordination struggles with task persistence heightened emotional reactivity needs structured routines
# Response: Based on the provided information, **Other specified body-focused repetitive behaviour (6B25.Y)** is the most likely diagnosis.
#
# Here's why:
#
# * **Recurrent Habitual Actions:** The user symptoms list several behaviors that could fall under this category, including "no proper pencil grips," "restless," and "impulsive behaviors." These actions are repetitive and directed at the integument (skin/body).
# * **Unsuccessful Attempts to Stop:** The context states a key feature is the inability to control the behavior.  While not explicitly stated in the symptoms, the phrasing "struggles with task persistence" and "needs structured routines" could imply difficulty controlling these actions.
# * **Significant Impact:** The symptoms list significant academic difficulties ("scholastic backwardness"), social challenges ("hyper gets excited easily," "difficulty sustaining attention"), and emotional reactivity. This aligns with the ICD-11 requirement that the behavior causes distress or impairment in functioning.
#
#
# **Important Disclaimer:**
#
# I am an AI chatbot and cannot provide medical advice. The information provided is for general knowledge purposes only and should not be considered a substitute for professional medical evaluation. It is essential to consult with a qualified healthcare professional for any health concerns or before making any decisions related to your health or treatment.
#
#
# Query: 7 not interested in studies doesnt read the question fully in examination finds difficulty in comprehending the text too emotional with peers mostly longing for acceptance with peers finds irritating to wear socks belts finds easy way out to avoid struggle difficulty in organizing stuff fussy eater loves sweets lacks patience needs immediate gratification slow processing speed challenges in reading comprehension poor organizational skills difficulty with sustained effort
# Response: Based on the provided symptoms, **Developmental learning disorder with impairment in reading (6A03.0)** appears to be the most likely diagnosis.
#
# Here's why:
#
# * **Reading Comprehension Difficulties:** The user explicitly states "finds difficulty in comprehending the text" and "challenges in reading comprehension." This aligns directly with the core feature of developmental learning disorder with impairment in reading.
# * **Academic Struggle:**  Symptoms like "7 not interested in studies," "doesnt read the question fully in examination," and "scholastic backwardness" indicate a significant struggle with academic tasks, consistent with this diagnosis.
# * **Organizational Issues:** "Difficulty in organizing stuff," "poor organizational skills," and "difficulty with sustained effort" are common challenges associated with developmental learning disorders.
# * **Additional Symptoms:**  The user's emotional sensitivity ("too emotional with peers"),  sensory aversions (socks, belts), preference for immediate gratification, and slow processing speed can all be associated with this disorder, though they may also point to other co-occurring conditions.
#
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for the advice of a qualified healthcare professional. A comprehensive evaluation by a doctor or specialist is necessary for an accurate diagnosis and treatment plan.
#
#
# Query: 8 aloof play lacks expressive language gibberish talks selfstimulating emotions limited eye contact lacks attention and concentration toilet training is not attained yet selftalk present stubborn sometimes in the morning interested in wearing new clothes like soft and comfortable clothes like water play low sitting tolerance repetitive behaviors limited social reciprocity sensory seeking behaviors difficulty with verbal communication
# Response: Based on the provided symptoms, the most likely diagnosis is **Autism Spectrum Disorder without Intellectual Disability and with Impaired Functional Language (6A02.2)**.
#
# Here's why:
#
# * **Limited Eye Contact, Aloof Play:** These are classic signs of autism.
# * **Lack of Expressive Language, Gibberish Talk, Self-Stimulating Behaviors:** This points towards significant difficulties with communication and social interaction, core features of autism.
# * **Delayed Verbal Communication, Difficulty with Verbal Communication:**  This reinforces the language impairment aspect.
# * **Limited Social Reciprocity:** Difficulty engaging in back-and-forth interactions is another hallmark of autism.
# * **Sensory Seeking Behaviors:** Many autistic individuals have heightened or unusual sensory sensitivities.
# * **Repetitive Behaviors:** This is a common characteristic of autism.
#
# While other diagnoses might share some symptoms, the combination of these factors strongly suggests Autism Spectrum Disorder with impaired functional language.
#
#
# **Important Disclaimer:** I am an AI chatbot and cannot provide medical advice. This information is for general knowledge purposes only and should not be considered a substitute for professional medical evaluation. It is crucial to consult a qualified healthcare professional for a comprehensive assessment and diagnosis.
#
#
# Query: 9 hyper echolalia toilet control not attained aloof play no eye contact stubborn sensorial sensitivities low sitting tolerance lacks nonverbal expressions responds to parents only no imitation self talking self laughing present robotic speech likes to throw objects listens to cartoons and music with very loud sound needs immediate gratification limited social engagement impulsive actions delayed speech development sensory processing issues
# Response: Based on the provided context and symptoms, the most likely diagnosis is **Other specified developmental speech or language Disorder (6A01.Y)**.
#
# Here's why:
#
# * **Persistent difficulties in communication:** The symptoms clearly indicate challenges with understanding and producing speech ("delayed speech development," "robotic speech," "unclear speech").
# * **Impairment in social communication:** The user exhibits limited social engagement, aloof play, lacks nonverbal expressions, responds only to parents, and has difficulty with eye contact.
# * **Sensory sensitivities and behaviors:**  "Sensorial sensitivities," "low sitting tolerance," and preference for loud sounds suggest sensory processing issues common in developmental speech and language disorders.
# * **Other symptoms:** The presence of echolalia, self-talking, self-laughing, throwing objects, and needing immediate gratification aligns with the profile of this disorder.
#
# **Disclaimer:** I am an AI chatbot and cannot provide medical diagnoses. This information is for educational purposes only and should not be substituted for a comprehensive evaluation by a qualified healthcare professional.
#
#
#
#
# Saved 55 diagnoses to /content/rag_diagnoses_all_symptoms.csv

# %%
# Step 6:Optional Start Ollama server and verify
def start_ollama_server():
    try:
        subprocess.Popen(["ollama", "serve"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        print("Starting Ollama server...")
        time.sleep(10)
        response = requests.get("http://127.0.0.1:11434")
        if response.status_code == 200:
            print("Ollama server is running at 127.0.0.1:11434")
        else:
            raise Exception("Ollama server failed to start")
    except requests.ConnectionError:
        print("Error: Could not connect to Ollama server.")
        raise
    except Exception as e:
        print(f"Error starting Ollama server: {e}")
        raise

start_ollama_server()

# Step 5: Pull MedLlama2 model if not already available
try:
    result = subprocess.run(["ollama", "list"], capture_output=True, text=True)
    if "MedLlama2" not in result.stdout:
        print("Pulling MedLlama2 model...")
        subprocess.run(["ollama", "pull", "MedLlama2"], check=True)
        print("Successfully pulled MedLlama2 model")
except subprocess.CalledProcessError as e:
    print(f"Error checking or pulling model: {e}")
    raise
